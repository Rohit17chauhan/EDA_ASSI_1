# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\\PW DATA SCIENCE\\EDA\\1\\winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.notna().count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.

# %%
Ans1=""" The key feature  of data set are as follows:

         1-All are in the form of numerical value.
         2-All data with a true vale meas no any row have NaN value.
         3-All data have fix number of record means each columns have 1599 record.
         4-All row  have a integer value.
         
         Feature:
         1-The data set have 12 feature.
         2-Each featre have a seperate column.
         3-Most of the  columns have integer and float value.
         4-These all value help to predict the data."""

# %%
Ans1
# Out:
# ' The key feature  of data set are as follows:\n\n         1-All are in the form of numerical value.\n         2-All data with a true vale meas no any row have NaN value.\n         3-All data have fix number of record means each columns have 1599 record.\n         4-All row  have a integer value.\n         \n         Feature:\n         1-The data set have 12 feature.\n         2-Each featre have a seperate column.\n         3-Most of the  columns have integer and float value.\n         4-These all value help to predict the data.'

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.

# %%
Ans2="""First we have to check is any row or columns have a missing value if yes then we have to fill it with df.fillna 
       if no nay row or column are missing the we have to perform next task.
       
       example:"""

# %%
Ans2
# Out:
# 'First we have to check is any row or columns have a missing value if yes then we have to fill it with df.fillna \n       if no nay row or column are missing the we have to perform next task.\n       \n       example:'

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
df.isnull().count()
# there is no any row or columns are missning
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
Ans2_1="""1. Dropping Missing Values
Description: Remove rows or columns with missing values.
Advantages:
Simplicity: Very easy to implement.
No Data Distortion: No assumptions are made about the missing data, so there no risk of introducing bias.
Disadvantages:
Data Loss: You lose potentially valuable information, especially if a significant portion of the data is missing.
Bias: If the missing data is not completely random, dropping rows or columns can introduce bias.
2. Mean/Median/Mode Imputation
Description: Replace missing values with the mean, median, or mode of the respective column.
Advantages:
Simplicity: Easy to implement and quick to compute.
Preserves Sample Size: No loss of data, as all rows are retained.
Disadvantages:
Distortion of Data Distribution: Imputing with the mean/median/mode can reduce the natural variance and lead to a distortion of the data distribution.
Underestimation of Variability: This method might underestimate the variability in the data, leading to biased estimates."""

# %%
Ans2_1
# Out:
# '1. Dropping Missing Values\nDescription: Remove rows or columns with missing values.\nAdvantages:\nSimplicity: Very easy to implement.\nNo Data Distortion: No assumptions are made about the missing data, so there no risk of introducing bias.\nDisadvantages:\nData Loss: You lose potentially valuable information, especially if a significant portion of the data is missing.\nBias: If the missing data is not completely random, dropping rows or columns can introduce bias.\n2. Mean/Median/Mode Imputation\nDescription: Replace missing values with the mean, median, or mode of the respective column.\nAdvantages:\nSimplicity: Easy to implement and quick to compute.\nPreserves Sample Size: No loss of data, as all rows are retained.\nDisadvantages:\nDistortion of Data Distribution: Imputing with the mean/median/mode can reduce the natural variance and lead to a distortion of the data distribution.\nUnderestimation of Variability: This method might underestimate the variability in the data, leadi
# ...

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?

# %%
std=pd.read_csv("E:\\PW DATA SCIENCE\\EDA\\1\\stud.csv")
std
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
Ans3=""" The key factors that affect students' performance in exams that the student take less test prepration exam mostly
         the student are not not completed there test prepration exam. 
         
         In the data set of student who completed there master degree, are good in mat score, reading score, and also in 
         writing score.
        
        we can analyze these all factore by different technique like:
        1 EDA
        2 Feature engineering
        3 ploting a garph etc."""
Ans3
# Out:
# " The key factors that affect students' performance in exams that the student take less test prepration exam mostly\n         the student are not not completed there test prepration exam. \n         \n         In the data set of student who completed there master degree, are good in mat score, reading score, and also in \n         writing score.\n        \n        we can analyze these all factore by different technique like:\n        1 EDA\n        2 Feature engineering\n        3 ploting a garph etc."

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?

# %%
Ans4="""Feature engineering is a critical step in preparing a dataset for modeling, especially in complex scenarios like predicting student performance. The process involves selecting, transforming, and creating new features to improve the model's predictive power. Here’s how you might approach feature engineering for a student performance dataset:

1. Understanding the Dataset
Before diving into feature engineering, it’s essential to thoroughly understand the dataset. The student performance dataset typically includes features like demographic information, parental background, study habits, previous grades, and other relevant factors that could influence academic outcomes.

2. Handling Missing Data
Imputation: If the dataset has missing values, imputing them is crucial. Techniques like mean/mode imputation or more advanced methods like KNN or MICE (Multiple Imputation by Chained Equations) can be used depending on the nature of the missing data.
Dropping Rows/Columns: If a feature has too many missing values, it might be better to drop that feature or those rows altogether.
3. Feature Selection
Correlation Analysis: Evaluate the correlation between each feature and the target variable (e.g., final grade). Features with high correlation to the target are likely to be more useful in the model.
Domain Knowledge: Use domain knowledge to select features that are known to impact student performance, such as parental education level, study time, or participation in extracurricular activities.
Chi-Square Test: For categorical variables, a chi-square test can help identify those that are statistically significant in relation to the target variable.
4. Feature Transformation
Scaling and Normalization:

Standardization: This technique rescales the data to have a mean of 0 and a standard deviation of 1. It’s particularly useful when the data is normally distributed.
Min-Max Scaling: This rescales the data to a fixed range, typically [0, 1]. It’s useful when the model (e.g., neural networks) is sensitive to the scale of features."""
Ans4
# Out:
# "Feature engineering is a critical step in preparing a dataset for modeling, especially in complex scenarios like predicting student performance. The process involves selecting, transforming, and creating new features to improve the model's predictive power. Here’s how you might approach feature engineering for a student performance dataset:\n\n1. Understanding the Dataset\nBefore diving into feature engineering, it’s essential to thoroughly understand the dataset. The student performance dataset typically includes features like demographic information, parental background, study habits, previous grades, and other relevant factors that could influence academic outcomes.\n\n2. Handling Missing Data\nImputation: If the dataset has missing values, imputing them is crucial. Techniques like mean/mode imputation or more advanced methods like KNN or MICE (Multiple Imputation by Chained Equations) can be used depending on the nature of the missing data.\nDropping Rows/Columns: If a feature h
# ...

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("E:\\PW DATA SCIENCE\\EDA\\1\\winequality-red.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.diff()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               0.4             0.180         0.00             0.7      0.022
# 2               0.0            -0.120         0.04            -0.3     -0.006
# 3               3.4            -0.480         0.52            -0.4     -0.017
# 4              -3.8             0.420        -0.56             0.0      0.001
# ...             ...               ...          ...             ...        ...
# 1594           -0.6            -0.020         0.00             0.1      0.022
# 1595           -0.3            -0.050         0.02             0.2     -0.028
# 1596            0.4            -0.040         0.03             0.1      0.014
# 1597           -0.4             0.135        -0.01            -0.3     -0.001
# 1598            0.1            -0.335         0.35             1.6     -0.008
#
# ...

# %%
plt.figure(figsize=(20,4))
sns.barplot(df)
# Out:
# <Axes: >

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

# %%
# Separating out the features
features = df.drop(columns=['quality'])  # Assuming 'quality' is the target variable

# Standardizing the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
features
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Perform PCA
pca = PCA()
pca.fit(scaled_features)

# Explained variance ratio for each principal component
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate cumulative explained variance
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# %%
# Plot cumulative explained variance
plt.figure(figsize=(8, 6))
plt.plot(np.arange(1, len(cumulative_explained_variance) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.title('Cumulative Explained Variance by Principal Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.show()

# %%
# Minimum number of components that explain 90% of the variance
n_components_90_variance = np.argmax(cumulative_explained_variance >= 0.90) + 1

n_components_90_variance
# Out:
# 7
